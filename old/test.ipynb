# %% [markdown]
# ### Horizontal line

# %%
# opt_result_three_horizontal_picture
opt = COBYLA(maxiter=150)
objective_func_vals = []
# make the plot nicer
plt.rcParams["figure.figsize"] = (12, 6)

start = time.time()

opt_result_three_horizontal_picture_64 = opt.minimize(
    fun=partial(
        cost_func_digits,
        qnn=qnn_64,
        train_images=three_horizontal_picture_64), x0=initial_point_64)
elapsed = time.time() - start
print(f"Fit in {elapsed:0.2f} seconds")
# Out:
# Fit in 14.57 seconds

# %%
# Test
test_qc_64 = QuantumCircuit(num_latent + num_trash)
test_qc_64 = test_qc_64.compose(fm_64)
ansatz_qc = ansatz(num_latent + num_trash)
test_qc_64 = test_qc_64.compose(ansatz_qc)
test_qc_64.barrier()
test_qc_64.reset(4)
test_qc_64.reset(3)
test_qc_64.barrier()
test_qc_64 = test_qc_64.compose(ansatz_qc.inverse())

# sample new images
for image in [test_three_horizontal_picture_64]:
    original_qc = fm_64.assign_parameters(image)
    original_sv = Statevector(original_qc).data
    original_sv = np.reshape(np.abs(original_sv) ** 2, image_resolution)

    param_values = np.concatenate((image, opt_result_three_horizontal_picture_64.x))
    output_qc = test_qc_64.assign_parameters(param_values)
    output_sv = Statevector(output_qc).data
    output_sv = np.reshape(np.abs(output_sv) ** 2, image_resolution)

    fig, (ax1, ax2) = plt.subplots(1, 2)
    ax1.imshow(original_sv)
    ax1.set_title("Input Data")
    ax2.imshow(output_sv)
    ax2.set_title("Output Data")
    plt.show()

# %% [markdown]
# ### Cross

# %%
# three_cross_picture_64
opt = COBYLA(maxiter=150)
objective_func_vals = []
# make the plot nicer
plt.rcParams["figure.figsize"] = (12, 6)

start = time.time()

opt_result_three_cross_picture_64 = opt.minimize(
    fun=partial(
        cost_func_digits,
        qnn=qnn_64,
        train_images=three_cross_picture_64), x0=initial_point_64)
elapsed = time.time() - start
print(f"Fit in {elapsed:0.2f} seconds")
# Out:
# Fit in 14.50 seconds

# %%
# Test
test_qc_64 = QuantumCircuit(num_latent + num_trash)
test_qc_64 = test_qc_64.compose(fm_64)
ansatz_qc = ansatz(num_latent + num_trash)
test_qc_64 = test_qc_64.compose(ansatz_qc)
test_qc_64.barrier()
test_qc_64.reset(4)
test_qc_64.reset(3)
test_qc_64.barrier()
test_qc_64 = test_qc_64.compose(ansatz_qc.inverse())

# sample new images
for image in [test_three_cross_picture_64]:
    original_qc = fm_64.assign_parameters(image)
    original_sv = Statevector(original_qc).data
    original_sv = np.reshape(np.abs(original_sv) ** 2, image_resolution)

    param_values = np.concatenate((image, opt_result_three_cross_picture_64.x))
    output_qc = test_qc_64.assign_parameters(param_values)
    output_sv = Statevector(output_qc).data
    output_sv = np.reshape(np.abs(output_sv) ** 2, image_resolution)

    fig, (ax1, ax2) = plt.subplots(1, 2)
    ax1.imshow(original_sv)
    ax1.set_title("Input Data")
    ax2.imshow(output_sv)
    ax2.set_title("Output Data")
    plt.show()

# %% [markdown]
# ### Diagonal Cross

# %%
# opt_result_three_horizontal_picture
opt = COBYLA(maxiter=150)
objective_func_vals = []
# make the plot nicer
plt.rcParams["figure.figsize"] = (12, 6)

start = time.time()

opt_result_three_diagonal_cross_picture_64 = opt.minimize(
    fun=partial(
        cost_func_digits,
        qnn=qnn_64,
        train_images=three_diagonal_cross_picture_64), x0=initial_point_64)
elapsed = time.time() - start
print(f"Fit in {elapsed:0.2f} seconds")
# Out:
# Fit in 14.35 seconds

# %%
# Test
test_qc_64 = QuantumCircuit(num_latent + num_trash)
test_qc_64 = test_qc_64.compose(fm_64)
ansatz_qc = ansatz(num_latent + num_trash)
test_qc_64 = test_qc_64.compose(ansatz_qc)
test_qc_64.barrier()
test_qc_64.reset(4)
test_qc_64.reset(3)
test_qc_64.barrier()
test_qc_64 = test_qc_64.compose(ansatz_qc.inverse())

# sample new images
for image in [test_three_diagonal_cross_picture_64]:
    original_qc = fm_64.assign_parameters(image)
    original_sv = Statevector(original_qc).data
    original_sv = np.reshape(np.abs(original_sv) ** 2, image_resolution)

    param_values = np.concatenate((image, opt_result_three_diagonal_cross_picture_64.x))
    output_qc = test_qc_64.assign_parameters(param_values)
    output_sv = Statevector(output_qc).data
    output_sv = np.reshape(np.abs(output_sv) ** 2, image_resolution)

    fig, (ax1, ax2) = plt.subplots(1, 2)
    ax1.imshow(original_sv)
    ax1.set_title("Input Data")
    ax2.imshow(output_sv)
    ax2.set_title("Output Data")
    plt.show()

# %% [markdown]
# ### Vertical Line

# %%
# opt_result_three_horizontal_picture
opt = COBYLA(maxiter=150)
objective_func_vals = []
# make the plot nicer
plt.rcParams["figure.figsize"] = (12, 6)

start = time.time()

opt_result_three_vertical_line_picture_64 = opt.minimize(
    fun=partial(
        cost_func_digits,
        qnn=qnn_64,
        train_images=three_vertical_line_picture_64), x0=initial_point_64)
elapsed = time.time() - start
print(f"Fit in {elapsed:0.2f} seconds")
# Out:
# Fit in 14.76 seconds

# %%
# Test
test_qc_64 = QuantumCircuit(num_latent + num_trash)
test_qc_64 = test_qc_64.compose(fm_64)
ansatz_qc = ansatz(num_latent + num_trash)
test_qc_64 = test_qc_64.compose(ansatz_qc)
test_qc_64.barrier()
test_qc_64.reset(4)
test_qc_64.reset(3)
test_qc_64.barrier()
test_qc_64 = test_qc_64.compose(ansatz_qc.inverse())

# sample new images
for image in [test_three_vertical_line_picture_64]:
    original_qc = fm_64.assign_parameters(image)
    original_sv = Statevector(original_qc).data
    original_sv = np.reshape(np.abs(original_sv) ** 2, image_resolution)

    param_values = np.concatenate((image, opt_result_three_vertical_line_picture_64.x))
    output_qc = test_qc_64.assign_parameters(param_values)
    output_sv = Statevector(output_qc).data
    output_sv = np.reshape(np.abs(output_sv) ** 2, image_resolution)

    fig, (ax1, ax2) = plt.subplots(1, 2)
    ax1.imshow(original_sv)
    ax1.set_title("Input Data")
    ax2.imshow(output_sv)
    ax2.set_title("Output Data")
    plt.show()

# %% [markdown]
# ### Dot

# %%
# opt_result_three_horizontal_picture
opt = COBYLA(maxiter=150)
objective_func_vals = []
# make the plot nicer
plt.rcParams["figure.figsize"] = (12, 6)

start = time.time()

opt_result_dot_picture_64 = opt.minimize(
    fun=partial(
        cost_func_digits,
        qnn=qnn_64,
        train_images=dot_picture_64), x0=initial_point_64)
elapsed = time.time() - start
print(f"Fit in {elapsed:0.2f} seconds")
# Out:
# Fit in 14.63 seconds

# %%
# Test
test_qc_64 = QuantumCircuit(num_latent + num_trash)
test_qc_64 = test_qc_64.compose(fm_64)
ansatz_qc = ansatz(num_latent + num_trash)
test_qc_64 = test_qc_64.compose(ansatz_qc)
test_qc_64.barrier()
test_qc_64.reset(4)
test_qc_64.reset(3)
test_qc_64.barrier()
test_qc_64 = test_qc_64.compose(ansatz_qc.inverse())

# sample new images
for image in [test_dot_picture_64]:
    original_qc = fm_64.assign_parameters(image)
    original_sv = Statevector(original_qc).data
    original_sv = np.reshape(np.abs(original_sv) ** 2, image_resolution)

    param_values = np.concatenate((image, opt_result_dot_picture_64.x))
    output_qc = test_qc_64.assign_parameters(param_values)
    output_sv = Statevector(output_qc).data
    output_sv = np.reshape(np.abs(output_sv) ** 2, image_resolution)

    fig, (ax1, ax2) = plt.subplots(1, 2)
    ax1.imshow(original_sv)
    ax1.set_title("Input Data")
    ax2.imshow(output_sv)
    ax2.set_title("Output Data")
    plt.show()

# %% [markdown]
# ## Tool for many figures at once
